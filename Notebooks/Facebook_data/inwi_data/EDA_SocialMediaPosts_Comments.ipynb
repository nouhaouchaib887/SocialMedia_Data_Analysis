# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import seaborn as sns

# %% [markdown]
# # Facebook _data_inwi

# %%
with open('../../../data/official_pages/facebook_data_backup/inwi.ma_facebook_posts_with_comments_20250601_035335.json', 'r', encoding='utf-8') as f:
    data = json.load(f)["data"]

# %%
print(f"Type des données chargées : {type(data)}")
# Out:
# Type des données chargées : <class 'list'>

# %%
posts_df = pd.DataFrame(data if isinstance(data, list) else [data])
if 'comments' in posts_df.columns:
    posts_df = posts_df.drop(columns=['comments'])

#Convertir created_time en datetime
posts_df['created_time'] = pd.to_datetime(posts_df['created_time'])

# %%
posts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   post_id              100 non-null    object
#  1   source_id            100 non-null    object
#  2   created_time         100 non-null    datetime64[ns]
#  3   permalink            100 non-null    object
#  4   page_id              100 non-null    object
#  5   page_name            100 non-null    object
#  6   message              100 non-null    object
#  7   media_type           100 non-null    object
#  8   media_url            100 non-null    object
#  9   thumbnail_url        100 non-null    object
#  10  can_share            100 non-null    bool
#  11  shares               100 non-null    int64
#  12  can_comment          100 non-null    bool
#  13  comments_count       100 non-null    int64
#  14  can_like             100 non-null    bool
#  15  like_count           100 non-null    int64
#  16  hashtags             100 non-null    object
#  17  mentions             100 non-null    object
#  18  platform             100 non-null    object
#  19  brand_name           100 non-null    object
#  20  kafka_metadata       100 non-null    object
#  21  collection_metadata  100 non-null    object
#  22  statistics           100 non-null    object
# dtypes: bool(3), datetime64[ns](1), int64(3), object(16)
# memory usage: 16.0+ KB

# %%
posts_df.isnull().sum()
# Out:
# post_id                0
# source_id              0
# created_time           0
# permalink              0
# page_id                0
# page_name              0
# message                0
# media_type             0
# media_url              0
# thumbnail_url          0
# can_share              0
# shares                 0
# can_comment            0
# comments_count         0
# can_like               0
# like_count             0
# hashtags               0
# mentions               0
# platform               0
# brand_name             0
# kafka_metadata         0
# collection_metadata    0
# statistics             0
# dtype: int64

# %%
# 1. Colonnes à vérifier pour présence de chaînes vides
text_fields = [
    "post_id", "source_id", "created_time", "permalink", "page_id",
    "page_name", "message", "media_type", "media_url", "thumbnail_url"
]

print("🧪 Champs texte vides :")
for col in text_fields:
    empty_count = (posts_df[col].astype(str).str.strip() == '').sum()
    print(f" - {col}: {empty_count} lignes vides")

# 2. Vérification created_time valide
print("\n🕒 Vérification des timestamps invalides :")
invalid_dates = pd.to_datetime(posts_df["created_time"], errors="coerce").isna().sum()
print(f" - created_time non valides : {invalid_dates}")

# 3. Valeurs uniques des booléens
print("\n🔁 Valeurs uniques booléennes :")
for col in ["can_share", "can_comment"]:
    print(f" - {col}: {posts_df[col].nunique()} valeurs uniques ({posts_df[col].unique()})")

# 4. Champs numériques à 0
print("\n🔢 Champs numériques avec des zéros :")
for col in ["shares", "comments_count", "like_count"]:
    zero_count = (posts_df[col] == 0).sum()
    print(f" - {col} == 0 : {zero_count} lignes")

# 5. Listes : type check et nombre de listes vides
print("\n📚 Vérification des champs listes :")
for col in ["hashtags", "mentions"]:
    non_lists = posts_df[~posts_df[col].apply(lambda x: isinstance(x, list))].shape[0]
    empty_lists = posts_df[posts_df[col].apply(lambda x: isinstance(x, list) and len(x) == 0)].shape[0]
    print(f" - {col} : {non_lists} non-listes / {empty_lists} listes vides")
# Out:
# 🧪 Champs texte vides :
#  - post_id: 0 lignes vides
#  - source_id: 0 lignes vides
#  - created_time: 0 lignes vides
#  - permalink: 0 lignes vides
#  - page_id: 0 lignes vides
#  - page_name: 0 lignes vides
#  - message: 1 lignes vides
#  - media_type: 1 lignes vides
#  - media_url: 1 lignes vides
#  - thumbnail_url: 1 lignes vides
#
# 🕒 Vérification des timestamps invalides :
#  - created_time non valides : 0
#
# 🔁 Valeurs uniques booléennes :
#  - can_share: 1 valeurs uniques ([ True])
#  - can_comment: 1 valeurs uniques ([ True])
#
# 🔢 Champs numériques avec des zéros :
#  - shares == 0 : 0 lignes
#  - comments_count == 0 : 0 lignes
#  - like_count == 0 : 0 lignes
#
# 📚 Vérification des champs listes :
#  - hashtags : 0 non-listes / 11 listes vides
#  - mentions : 0 non-listes / 100 listes vides

# %%
posts_df = posts_df.drop(columns=["kafka_metadata", "collection_metadata", "statistics"])

# %%
 #Ajouter des colonnes utiles
posts_df['day'] = posts_df['created_time'].dt.date
posts_df['hour'] = posts_df['created_time'].dt.hour
posts_df['message_length'] = posts_df['message'].fillna('').apply(len)

# %%
#Aperçu général
print(posts_df.describe(include='all'))
print(posts_df.dtypes)
print(posts_df.head())
print(posts_df["post_id"].nunique())
# Out:
#                  post_id        source_id                   created_time  \
# count                100              100                            100
# unique               100                1                            NaN
# top     1088318753342933  100064944541507                            NaN
# freq                   1              100                            NaN
# mean                 NaN              NaN  2025-04-23 21:31:25.929999872
# min                  NaN              NaN            2025-03-16 22:53:20
# 25%                  NaN              NaN            2025-03-30 21:18:22
# 50%                  NaN              NaN            2025-04-26 01:25:30
# 75%                  NaN              NaN            2025-05-13 14:44:42
# max                  NaN              NaN            2025-05-31 21:18:44
# std                  NaN              NaN                            NaN
#
#                                                 permalink          page_id  \
# count                                                 100              100
# unique                                                100                1
# top     https://www.facebook.com/inwi.ma/posts/1088318...  100064944541507
# freq                                                    1              100
# mean                                                  NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
# std                                                   NaN              NaN
#
#        page_name                                            message  \
# count        100                                                100
# unique         1                                                 87
# top      inwi.ma  مع عرض نجمة 6 ديال inwi استفدوا من اللامحدود ع...
# freq         100                                                  4
# mean         NaN                                                NaN
# min          NaN                                                NaN
# 25%          NaN                                                NaN
# 50%          NaN                                                NaN
# 75%          NaN                                                NaN
# max          NaN                                                NaN
# std          NaN                                                NaN
#
#        media_type                                          media_url  \
# count         100                                                100
# unique          3                                                100
# top         Photo  https://www.facebook.com/inwi.ma/videos/136386...
# freq           69                                                  1
# mean          NaN                                                NaN
# min           NaN                                                NaN
# 25%           NaN                                                NaN
# 50%           NaN                                                NaN
# 75%           NaN                                                NaN
# max           NaN                                                NaN
# std           NaN                                                NaN
#
#                                             thumbnail_url  ... can_like  \
# count                                                 100  ...      100
# unique                                                100  ...        1
# top     https://scontent-qro1-2.xx.fbcdn.net/v/t15.525...  ...     True
# freq                                                    1  ...      100
# mean                                                  NaN  ...      NaN
# min                                                   NaN  ...      NaN
# 25%                                                   NaN  ...      NaN
# 50%                                                   NaN  ...      NaN
# 75%                                                   NaN  ...      NaN
# max                                                   NaN  ...      NaN
# std                                                   NaN  ...      NaN
#
#           like_count     hashtags  mentions  platform  brand_name         day  \
# count     100.000000          100       100       100         100         100
# unique           NaN           11         1         1           1          56
# top              NaN  [inwi_M3ak]        []  facebook     inwi.ma  2025-05-28
# freq             NaN           68       100       100         100           4
# mean     5862.940000          NaN       NaN       NaN         NaN         NaN
# min       311.000000          NaN       NaN       NaN         NaN         NaN
# 25%      2576.250000          NaN       NaN       NaN         NaN         NaN
# 50%      4110.000000          NaN       NaN       NaN         NaN         NaN
# 75%      6562.500000          NaN       NaN       NaN         NaN         NaN
# max     22232.000000          NaN       NaN       NaN         NaN         NaN
# std      4921.549768          NaN       NaN       NaN         NaN         NaN
#
#               hour message_length    month
# count   100.000000     100.000000      100
# unique         NaN            NaN        3
# top            NaN            NaN  2025-05
# freq           NaN            NaN       44
# mean     14.920000     120.070000      NaN
# min       0.000000       0.000000      NaN
# 25%      10.750000      87.250000      NaN
# 50%      15.000000     110.000000      NaN
# 75%      19.000000     153.750000      NaN
# max      23.000000     285.000000      NaN
# std       5.018511      57.171239      NaN
#
# [11 rows x 24 columns]
# post_id                   object
# source_id                 object
# created_time      datetime64[ns]
# permalink                 object
# page_id                   object
# page_name                 object
# message                   object
# media_type                object
# media_url                 object
# thumbnail_url             object
# can_share                   bool
# shares                     int64
# can_comment                 bool
# comments_count             int64
# can_like                    bool
# like_count                 int64
# hashtags                  object
# mentions                  object
# platform                  object
# brand_name                object
# day                       object
# hour                       int32
# message_length             int64
# month                     object
# dtype: object
#             post_id        source_id        created_time  \
# 0  1088318753342933  100064944541507 2025-05-31 21:18:44
# 1  1087947426713399  100064944541507 2025-05-31 10:00:20
# 2  1087194276788714  100064944541507 2025-05-30 09:31:15
# 3  1082419163932892  100064944541507 2025-05-30 08:30:00
# 4  1086075516900590  100064944541507 2025-05-28 19:23:31
#
#                                            permalink          page_id  \
# 0  https://www.facebook.com/inwi.ma/posts/1088318...  100064944541507
# 1  https://www.facebook.com/inwi.ma/posts/1087947...  100064944541507
# 2  https://www.facebook.com/inwi.ma/posts/1087194...  100064944541507
# 3  https://www.facebook.com/inwi.ma/posts/1082419...  100064944541507
# 4  https://www.facebook.com/inwi.ma/posts/1086075...  100064944541507
#
#   page_name                                            message media_type  \
# 0   inwi.ma                    هنيئا أشرف، شكرا يا بطل !🇲🇦🇲🇦🇲🇦      Video
# 1   inwi.ma  النجمة 6 بقات ليها غير يومين وترجع 🤩🤩\nشكون ال...      Photo
# 2   inwi.ma  اللا محدود ديال محبوبة الجماهير ما بقى ليه واا...      Photo
# 3   inwi.ma                      تتمنى لكم inwi جمعة مباركة. 🌸
# 4   inwi.ma  النجمة 6 كتدوز آخر أيام العطلة ديالها قبل ما ت...      Photo
#
#                                            media_url  \
# 0  https://www.facebook.com/inwi.ma/videos/136386...
# 1  https://www.facebook.com/photo/?fbid=108794738...
# 2  https://www.facebook.com/photo/?fbid=108719225...
# 3
# 4  https://www.facebook.com/photo/?fbid=108607548...
#
#                                        thumbnail_url  ...  can_like  \
# 0  https://scontent-qro1-2.xx.fbcdn.net/v/t15.525...  ...      True
# 1  https://scontent-qro1-2.xx.fbcdn.net/v/t39.308...  ...      True
# 2  https://scontent-qro1-1.xx.fbcdn.net/v/t39.308...  ...      True
# 3                                                     ...      True
# 4  https://scontent-atl3-2.xx.fbcdn.net/v/t39.308...  ...      True
#
#    like_count     hashtags  mentions  platform  brand_name         day hour  \
# 0        2265           []        []  facebook     inwi.ma  2025-05-31   21
# 1         915  [inwi_M3ak]        []  facebook     inwi.ma  2025-05-31   10
# 2       11770  [inwi_M3ak]        []  facebook     inwi.ma  2025-05-30    9
# 3        1251           []        []  facebook     inwi.ma  2025-05-30    8
# 4       10766           []        []  facebook     inwi.ma  2025-05-28   19
#
#   message_length    month
# 0             31  2025-05
# 1             78  2025-05
# 2             98  2025-05
# 3             29  2025-05
# 4            100  2025-05
#
# [5 rows x 24 columns]
# 100

# %%
# 1. Histogramme des likes
plt.figure(figsize=(8, 4))
plt.hist(posts_df['like_count'], bins=20, color='orchid')
plt.title("Distribution des likes par post")
plt.xlabel("Likes")
plt.ylabel("Nombre de posts")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.hist(posts_df['comments_count'], bins=20, color='skyblue')
plt.title("Distribution des commentaires par post")
plt.xlabel("Commentaires")
plt.ylabel("Nombre de posts")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
posts_df['month'] = posts_df['created_time'].dt.to_period('M').astype(str)

# 3. Compter les posts par mois
posts_per_month = posts_df.groupby('month').size().reset_index(name='count')

# 4. Afficher les valeurs
print(posts_per_month)

# 5. Visualisation
plt.figure(figsize=(10, 5))
plt.bar(posts_per_month['month'], posts_per_month['count'], color='steelblue')
plt.title("Nombre de posts par mois")
plt.xlabel("Mois")
plt.ylabel("Nombre de posts")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#      month  count
# 0  2025-03     29
# 1  2025-04     27
# 2  2025-05     44

# %%
# Longueur des messages
plt.figure(figsize=(8, 4))
plt.hist(posts_df['message_length'], bins=30, color='tomato')
plt.title("Longueur des messages")
plt.xlabel("Nombre de caractères")
plt.ylabel("Nombre de posts")
plt.tight_layout()
plt.show()

# %%
all_comments = []

for post in data:
    comments = post.get('comments', [])
    
    # Vérifie que la liste n'est pas vide
    if comments:
        for comment in comments:
            # Extraire uniquement les commentaires avec metadata valide
            metadata = comment.get('comment_metadata', {})
            if 'parent_post_id' in metadata:
                comment_flat = {
                    'comment_id': comment.get('comment_id'),
                    'message': comment.get('message'),
                    'created_time': comment.get('created_time'),
                    'like_count': int(comment.get('like_count', 0)),
                    'reply_count': comment.get('reply_count', 0),
                    'user_id': comment.get('user_id'),
                    'user_name': comment.get('user_name'),
                    'comment_url': comment.get('comment_url'),
                    'parent_post_id': metadata['parent_post_id'],
                    'comment_length': metadata.get('comment_length'),
                    'comment_engagement_score': metadata.get('comment_engagement_score'),
                    'has_hashtags': metadata.get('has_hashtags'),
                    'has_mentions': metadata.get('has_mentions'),
                    'platform': comment.get('platform'),
                    'brand_name': comment.get('brand_name')
                }
                all_comments.append(comment_flat)

# Créer le DataFrame à partir de la liste
comments_df = pd.DataFrame(all_comments)

# Conversion en datetime
comments_df['created_time'] = pd.to_datetime(comments_df['created_time'])

# Aperçu
print(comments_df.head())
# Out:
#          comment_id                                            message  \
# 0  1818153165710217  Vous n avez aucune honte ?!! 3 mois que je pay...
# 1   563603726619009              الف مبروك عليك يااسد اشرف حكيمي مرحبا
# 2   682503821419212                    حنا معاك انوي وباقين نويت الخير
# 3  1853962871839803           ريزو من صباح هو مقطوع علينا شوفو لينا حل
# 4   711159261279085  سلام أنا بدلت فورفي أو خلصت من ماي إنوي ولكن م...
#
#                created_time  like_count  reply_count  \
# 0 2025-05-31 22:06:58+00:00           3            1
# 1 2025-05-31 23:00:45+00:00           0            0
# 2 2025-06-01 00:14:27+00:00           0            0
# 3 2025-05-31 21:24:54+00:00           2            2
# 4 2025-05-31 23:55:32+00:00           0            0
#
#                                              user_id       user_name  \
# 0  pfbid02x6QLq6J3T6WJGrdtSVp3tffdcB9jPoTxyj3zPYt...   Sanaâ Haimeur
# 1                                    100078164396275    Said Beddiaf
# 2  pfbid023C9Nw91tucgBP5sLSXtvUsdL4krZMkUnbMVGoLk...      Lotfi Raof
# 3  pfbid02PEU888fFYXJQ76d1ePJUVw8LHytWs9PbY5uJef8...     مريم الزعيم
# 4                                    100012994572743  Elgourch Ayoub
#
#                                          comment_url    parent_post_id  \
# 0  https://www.facebook.com/inwi.ma/videos/136386...  1088318753342933
# 1  https://www.facebook.com/inwi.ma/videos/136386...  1088318753342933
# 2  https://www.facebook.com/inwi.ma/videos/136386...  1088318753342933
# 3  https://www.facebook.com/inwi.ma/videos/136386...  1088318753342933
# 4  https://www.facebook.com/inwi.ma/videos/136386...  1088318753342933
#
#    comment_length  comment_engagement_score  has_hashtags  has_mentions  \
# 0             376                         4         False         False
# 1              37                         0         False         False
# 2              31                         0         False         False
# 3              40                         4         False         False
# 4             107                         0         False         False
#
#    platform brand_name
# 0  facebook    inwi.ma
# 1  facebook    inwi.ma
# 2  facebook    inwi.ma
# 3  facebook    inwi.ma
# 4  facebook    inwi.ma

# %%
comments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20804 entries, 0 to 20803
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   comment_id                20804 non-null  object
#  1   message                   20804 non-null  object
#  2   created_time              20804 non-null  datetime64[ns, UTC]
#  3   like_count                20804 non-null  int64
#  4   reply_count               20804 non-null  int64
#  5   user_id                   20804 non-null  object
#  6   user_name                 20804 non-null  object
#  7   comment_url               20804 non-null  object
#  8   parent_post_id            20804 non-null  object
#  9   comment_length            20804 non-null  int64
#  10  comment_engagement_score  20804 non-null  int64
#  11  has_hashtags              20804 non-null  bool
#  12  has_mentions              20804 non-null  bool
#  13  platform                  20804 non-null  object
#  14  brand_name                20804 non-null  object
# dtypes: bool(2), datetime64[ns, UTC](1), int64(4), object(8)
# memory usage: 2.1+ MB

# %%
comments_df["comment_id"].nunique()
# Out:
# 20774

# %%
# 1. Trouver les comment_id dupliqués
duplicated_ids = comments_df['comment_id'][comments_df['comment_id'].duplicated()]

# 2. Accéder aux lignes complètes avec ces comment_id
duplicated_comments = comments_df[comments_df['comment_id'].isin(duplicated_ids)]

# 3. Afficher les résultats
print(f"Nombre de commentaires dupliqués : {duplicated_comments.shape[0]}")
print(duplicated_comments[['comment_id', 'message', 'created_time']])
# Out:
# Nombre de commentaires dupliqués : 60
#             comment_id                                            message  \
# 1      563603726619009              الف مبروك عليك يااسد اشرف حكيمي مرحبا
# 3     1853962871839803           ريزو من صباح هو مقطوع علينا شوفو لينا حل
# 10    1853962871839803           ريزو من صباح هو مقطوع علينا شوفو لينا حل
# 11     563603726619009              الف مبروك عليك يااسد اشرف حكيمي مرحبا
# 60    2513603622323520                                             inwi👎👎
# 64    1402635677620748                  نهار الإثنين نفيق نلقا العرض هههه
# 65     998381729043591                     شمن عرض ريزو مقطوع هادي 3 ايام
# 68     998381729043591                     شمن عرض ريزو مقطوع هادي 3 ايام
# 69    1402635677620748                  نهار الإثنين نفيق نلقا العرض هههه
# 78    2513603622323520                                             inwi👎👎
# 89    1611002842908144                           Nujama sta imta ghatrja3
# 97    1611002842908144                           Nujama sta imta ghatrja3
# 284   2536015093398619                                             توحشنه
# 286   2536015093398619                                             توحشنه
# 1637   668529419426268                                        عندها مليحة
# 1642   668529419426268                                        عندها مليحة
# 2134   712885074616549   خدمة Semme3ni لا تعمل على الموقع لاختيار النغمات
# 2136   712885074616549   خدمة Semme3ni لا تعمل على الموقع لاختيار النغمات
# 2747  1194505785754949              واش الى درت *2 كتعطيك هضرة وكونيكسيو؟
# 2749  1194505785754949              واش الى درت *2 كتعطيك هضرة وكونيكسيو؟
# 2766  1399582701358121  أنا خلصت abonn ديال الشهر و لكن ممطلوقاش عندي ...
# 2768  1399582701358121  أنا خلصت abonn ديال الشهر و لكن ممطلوقاش عندي ...
# 2777   693236176420475                        رجعو 6* راه تقهرت بزيرو 😭😂😂
# 2779   693236176420475                        رجعو 6* راه تقهرت بزيرو 😭😂😂
# 3051   720285584010682                      ايمتا غيرجع لعرض ديال نجة ستة
# 3055   712002147864276      شنو ندير إلا بغيت نعرف شحال باقي عندي من جيكا
# 3056  1424171969019378                   كيفاش نعرف فوقاش كيتسالا الصولد؟
# 3062   720285584010682                      ايمتا غيرجع لعرض ديال نجة ستة
# 3063  1424171969019378                   كيفاش نعرف فوقاش كيتسالا الصولد؟
# 3065   712002147864276      شنو ندير إلا بغيت نعرف شحال باقي عندي من جيكا
# 3684   704959305450686               ولو عمرنا شنا شي حجا 250درهم كول شهر
# 3692   729118296318946                  الرقم ديال inwi الى بغيت نتصل بهم
# 3693   704959305450686               ولو عمرنا شنا شي حجا 250درهم كول شهر
# 3695   670843622411365                                      وش كين نجمه 6
# 3699   729118296318946                  الرقم ديال inwi الى بغيت نتصل بهم
# 3701   670843622411365                                      وش كين نجمه 6
# 4141  1840347230148908  الله يوفقهم في مستقبلهم انشاء الله وخليهم لوال...
# 4142  1840347230148908  الله يوفقهم في مستقبلهم انشاء الله وخليهم لوال...
# 4146  1368540724382202                                   واش عرض 6*  باقي
# 4151  1125609442897114  بالحزم والتفاني وصلت كرة القدم المغربية لما وص...
# 4152  1368540724382202                                   واش عرض 6*  باقي
# 4153  1125609442897114  بالحزم والتفاني وصلت كرة القدم المغربية لما وص...
# 4160  1424435662058320  العقوبة للكبار يتخوزقو ونتهناو من فريع الراس د...
# 4162  1424435662058320  العقوبة للكبار يتخوزقو ونتهناو من فريع الراس د...
# 4313  1884766938947339                       فوقاش لاعبين هذا ان شاء الله
# 4315  1884766938947339                       فوقاش لاعبين هذا ان شاء الله
# 4412  1047917803886192                        واش باقي العرض ولا تسالا ؟؟
# 4413  1047917803886192                        واش باقي العرض ولا تسالا ؟؟
# 4897  1785715812357230                                     وقت اسالي عرض؟
# 4900   709896541532449                                         كين عرض *6
# 4902   660235150175283       inwi \nيعني لا شارجيت ليوما 17 ماي غتقبل ليا
# 4903   709896541532449                                         كين عرض *6
# 4905  1785715812357230                                     وقت اسالي عرض؟
# 4908   660235150175283       inwi \nيعني لا شارجيت ليوما 17 ماي غتقبل ليا
# 5189  1618903605452454                                              Chfra
# 5191  1618903605452454                                              Chfra
# 6121  1214572300344481  اللهم يسر انك محبوب الجماهير سير على بركة الله...
# 6122  1214572300344481  اللهم يسر انك محبوب الجماهير سير على بركة الله...
# 7595  4028586984085585                               واش عرض *6 مزال كاين
# 7597  4028586984085585                               واش عرض *6 مزال كاين
#
#                   created_time
# 1    2025-05-31 23:00:45+00:00
# 3    2025-05-31 21:24:54+00:00
# 10   2025-05-31 21:24:54+00:00
# 11   2025-05-31 23:00:45+00:00
# 60   2025-06-01 00:23:04+00:00
# 64   2025-05-31 13:40:24+00:00
# 65   2025-05-31 19:45:28+00:00
# 68   2025-05-31 19:45:28+00:00
# 69   2025-05-31 13:40:24+00:00
# 78   2025-06-01 00:23:04+00:00
# 89   2025-05-31 23:47:47+00:00
# 97   2025-05-31 23:47:47+00:00
# 284  2025-05-30 12:36:39+00:00
# 286  2025-05-30 12:36:39+00:00
# 1637 2025-05-29 22:09:10+00:00
# 1642 2025-05-29 22:09:10+00:00
# 2134 2025-05-26 23:33:49+00:00
# 2136 2025-05-26 23:33:49+00:00
# 2747 2025-05-27 17:52:02+00:00
# 2749 2025-05-27 17:52:02+00:00
# 2766 2025-05-24 21:29:41+00:00
# 2768 2025-05-24 21:29:41+00:00
# 2777 2025-05-26 11:17:07+00:00
# 2779 2025-05-26 11:17:07+00:00
# 3051 2025-05-24 07:59:56+00:00
# 3055 2025-05-24 00:07:42+00:00
# 3056 2025-05-24 10:59:04+00:00
# 3062 2025-05-24 07:59:56+00:00
# 3063 2025-05-24 10:59:04+00:00
# 3065 2025-05-24 00:07:42+00:00
# 3684 2025-05-21 14:04:49+00:00
# 3692 2025-05-21 16:19:34+00:00
# 3693 2025-05-21 14:04:49+00:00
# 3695 2025-05-21 17:04:28+00:00
# 3699 2025-05-21 16:19:34+00:00
# 3701 2025-05-21 17:04:28+00:00
# 4141 2025-05-19 14:16:15+00:00
# 4142 2025-05-19 14:16:15+00:00
# 4146 2025-05-18 20:24:22+00:00
# 4151 2025-05-19 02:42:13+00:00
# 4152 2025-05-18 20:24:22+00:00
# 4153 2025-05-19 02:42:13+00:00
# 4160 2025-05-19 05:49:35+00:00
# 4162 2025-05-19 05:49:35+00:00
# 4313 2025-05-18 12:21:45+00:00
# 4315 2025-05-18 12:21:45+00:00
# 4412 2025-05-19 08:28:52+00:00
# 4413 2025-05-19 08:28:52+00:00
# 4897 2025-05-17 22:57:15+00:00
# 4900 2025-05-17 22:07:18+00:00
# 4902 2025-05-17 18:18:21+00:00
# 4903 2025-05-17 22:07:18+00:00
# 4905 2025-05-17 22:57:15+00:00
# 4908 2025-05-17 18:18:21+00:00
# 5189 2025-05-17 00:49:42+00:00
# 5191 2025-05-17 00:49:42+00:00
# 6121 2025-05-12 18:58:50+00:00
# 6122 2025-05-12 18:58:50+00:00
# 7595 2025-05-07 12:42:22+00:00
# 7597 2025-05-07 12:42:22+00:00

# %%
print(comments_df.shape)
print(comments_df.dtypes)
comments_df.head()
# Out:
# (20804, 15)
# comment_id                               object
# message                                  object
# created_time                datetime64[ns, UTC]
# like_count                                int64
# reply_count                               int64
# user_id                                  object
# user_name                                object
# comment_url                              object
# parent_post_id                           object
# comment_length                            int64
# comment_engagement_score                  int64
# has_hashtags                               bool
# has_mentions                               bool
# platform                                 object
# brand_name                               object
# dtype: object
#          comment_id                                            message  \
# 0  1818153165710217  Vous n avez aucune honte ?!! 3 mois que je pay...
# 1   563603726619009              الف مبروك عليك يااسد اشرف حكيمي مرحبا
# 2   682503821419212                    حنا معاك انوي وباقين نويت الخير
# 3  1853962871839803           ريزو من صباح هو مقطوع علينا شوفو لينا حل
# 4   711159261279085  سلام أنا بدلت فورفي أو خلصت من ماي إنوي ولكن م...
#
#                created_time  like_count  reply_count  \
# 0 2025-05-31 22:06:58+00:00           3            1
# 1 2025-05-31 23:00:45+00:00           0            0
# 2 2025-06-01 00:14:27+00:00           0            0
# 3 2025-05-31 21:24:54+00:00           2            2
# 4 2025-05-31 23:55:32+00:00           0            0
#
#                                              user_id       user_name  \
# 0  pfbid02x6QLq6J3T6WJGrdtSVp3tffdcB9jPoTxyj3zPYt...   Sanaâ Haimeur
# 1                                    100078164396275    Said Beddiaf
# 2  pfbid023C9Nw91tucgBP5sLSXtvUsdL4krZMkUnbMVGoLk...      Lotfi Raof
# 3  pfbid02PEU888fFYXJQ76d1ePJUVw8LHytWs9PbY5uJef8...     مريم الزعيم
# 4                                    100012994572743  Elgourch Ayoub
#
#                                          comment_url    parent_post_id  \
# 0  https://www.facebook.com/inwi.ma/videos/136386...  1088318753342933
# 1  https://www.facebook.com/inwi.ma/videos/136386...  1088318753342933
# 2  https://www.facebook.com/inwi.ma/videos/136386...  1088318753342933
# 3  https://www.facebook.com/inwi.ma/videos/136386...  1088318753342933
# 4  https://www.facebook.com/inwi.ma/videos/136386...  1088318753342933
#
#    comment_length  comment_engagement_score  has_hashtags  has_mentions  \
# 0             376                         4         False         False
# 1              37                         0         False         False
# 2              31                         0         False         False
# 3              40                         4         False         False
# 4             107                         0         False         False
#
#    platform brand_name
# 0  facebook    inwi.ma
# 1  facebook    inwi.ma
# 2  facebook    inwi.ma
# 3  facebook    inwi.ma
# 4  facebook    inwi.ma

# %%
plt.figure(figsize=(8,4))
sns.histplot(comments_df['comment_length'], bins=30, kde=True)
plt.title("Distribution de la longueur des commentaires")
plt.xlabel("Nombre de caractères")
plt.ylabel("Fréquence")
plt.show()

# %%
message = comments_df[comments_df["comment_length"] > 4000]["message"].iloc[0]
print(message)
# Out:
# سبحان الله و الحمدلله و لا إله إلا الله و الله أكبر ولا حول ولاقوة الا بالله العلي العظيم. اللهم صل وسلم على نبينا محمد. سبحان الله وبحمده سبحان الله العظيم.#مليارات_الحسنات_لا_تعد_ولا_تحصى إغتنموا ثوابها#
# 🔸سبحان الله عدد ماخلق
# 🔸سبحان الله ملء ماخلق
# 🔸سبحان الله عدد مافي السموات والارض
# 🔸سبحان الله ملء مافي السموات والارض
# 🔸سبحان الله عدد ما أحصى كتابه
# 🔸 سبحان الله ملء ما أحصى كتابه
# 🔸سبحان الله عدد كل شيء
# 🔸سبحان الله ملء كل شيء
# 🔸سبحان الله عدد خلقه ورضا نفسه وزنة عرشه ومداد كلماته
# 🔶سبحان الله عدد ورق الأشجار وعدد حصي الجبال
#  وعدد قطرات الأمطار وعدد حبات الرمال
# 🔹لا إله إلا الله عدد ما خلق
# 🔹لا إله إلا الله ملء ما خلق
# 🔹لا إله إلا الله عدد مافي السموات والأرض
# 🔹لا إله إلا الله ملء مافي السموات والأرض
# 🔹لا إله إلا الله عدد ما أحصى كتابه
# 🔹لا إله إلا الله ملء ما أحصى كتابه
# 🔹لا إله إلا الله عدد كل شيء
# 🔹لا إله إلا الله ملء كل شيء
# 🔹لا إله إلا الله عدد خلقه ورضا نفسه وزنة عرشه ومداد كلماته
# 🔷لا إله إلا الله عدد ورق الأشجار وعدد حصي الجبال وعدد قطرات الأمطار وعدد حبات الرمال
# 🔸الحمد لله عدد ماخلق
# 🔸الحمد لله ملء ماخلق
# 🔸الحمد لله عدد مافي السموات والارض
# 🔸الحمد لله ملء مافي السموات والارض
# 🔸الحمد لله عدد ما أحصى كتابه
# 🔸الحمد لله ملء ما أحصى كتابه
# 🔸الحمد لله عدد كل شيء
# 🔸الحمد لله ملء كل شيء
# 🔸الحمد لله عدد خلقه ورضا نفسه وزنة عرشه ومداد كلماته
# 🔶الحمدلله عدد ورق الأشجار وعدد حصي الجبال
# وعدد قطرات الأمطار وعدد حبات الرمال
# 🔹الله أكبر عدد ماخلق
# 🔹الله أكبر ملء ماخلق
# 🔹الله أكبر عدد مافي السموات والارض
# 🔹 الله أكبر ملء مافي السموات والارض
# 🔹الله أكبر عدد ما أحصى كتابه
# 🔹الله أكبر ملء ما أحصى كتابه
# 🔹الله أكبر عدد كل شيء
# 🔹الله أكبر ملء كل شيء
# 🔹الله أكبر عدد خلقه ورضا نفسه وزنة عرشه ومداد كلماته
# 🔷الله أكبر عدد ورق الأشجار وعدد حصي الجبال وعدد قطرات الأمطار وعدد حبات الرمال
# 🔸استغفر الله عدد ماخلق
# 🔸استغفر الله ملء ماخلق
# 🔸 استغفر الله عدد مافي السموات والارض
# 🔸استغفر الله ملء مافي السموات والارض
# 🔸استغفر الله عدد ما أحصى كتابه
# 🔸 استغفر الله ملء ما أحصى كتابه
# 🔸استغفر الله عدد كل شيء
# 🔸استغفر الله ملء كل شيء
# 🔸استغفر الله عدد خلقه ورضا نفسه وزنة عرشه ومداد كلماته
# 🔶أستغفر الله عدد ورق الأشجار وعدد حصي الجبال
# وعدد قطرات الأمطار وعدد حبات الرمال
# 🔹لاحول ولاقوة الا بالله عدد ما خلق
# 🔹 لا حول ولا قوة الا بالله ملء ما خلق
# 🔹لا حول ولا قوة الا بالله عدد مافي السموات والأرض
# 🔹لاحول ولاقوة الا بالله ملء ما في السماوات والأرض
# 🔹لاحول ولاقوة الا بالله عدد ما أحصى كتابه
# 🔹لاحول ولاقوة الا بالله ملء ما أحصى كتابه
# 🔹لاحول ولاقوة الا بالله عدد كل شيء
# 🔹لاحول ولاقوة الا بالله ملء كل شيء
# 🔹لا حول ولا قوة الا بالله عدد خلقه ورضا نفسه وزنة عرشه ومداد كلماته
# 🔷لا حول ولا قوه إلا بالله عدد ورق الأشجار وعدد حصي الجبال وعدد قطرات الأمطار وعدد حبات الرمال
# 🔸اللهم صل وسلم على نبينا محمد عدد ما خلقت
# 🔸اللهم صل وسلم على نبينا محمد ملء ما خلقت
# 🔸اللهم صل وسلم على نبينا محمد عدد ما أحصى كتابك
# 🔸 اللهم صل وسلم على نبينا محمدملء ما أحصى كتابك
# 🔸اللهم صل وسلم على نبينا محمد عدد كل شيء
# 🔸اللهم صل وسلم على نبينا محمد ملء كل شيء
# 🔸اللهم صل وسلم على نبينا محمد عدد ما في السماوات والأرض
# 🔸اللهم صل وسلم على نبينا محمد ملء ما في السماوات والأرض
# 🔸اللهم صل وسلم على نبينا محمد عدد خلقك ورضا نفسك وزنة عرشك ومداد كلماتك
# 🔶اللهم صل وسلم على نبينا محمد عدد ورق الأشجار
# وعدد حصي الجبال وعدد قطرات الأمطار وعدد حبات الرمال.
# يا أرحم الراحمين
# يا أرحم الراحمين
# يا أرحم الراحمين
# ♦️اللهم مالك الملك تؤتي الملك من تشاء وتنزع الملك ممن تشاء وتعز من تشاء وتذل من تشاء بيدك الخير انك على كل شئ قدير تولج الليل في النهار وتولج النهار في الليل وتخرج الحي من الميت وتخرج الميت من الحي وترزق من تشاء بغير حساب رحمان الدنيا والآخرة ورحيمهما تعطي من تشاء منهما وتمنع من تشاء ارحمني رحمه تغنني عن من سواك
#
#  ♦️  اللهم إني أعوذ بك من غلبة الدين وغلبة العدو، اللهم إني أعوذ بك من جهد البلاء ومن درك الشقاء ومن سوء القضاء ومن شماتة الأعداء، اللهم أصلح لي ديني الذي هو عصمة أمري، وأصلح لي دنياي التي فيها معاشي، وأصلح لي آخرتي التي فيها معادي، واجعل الحياة زيادة لي في كل خير، واجعل الموت راحة لي من كل شر.
# ♦️اللهم أنت ربي لا إله إلا أنت خلقتني وأنا عبدك وأنا على عهدك ووعدك ما استطعت، أعوذ بك من شر ما صنعت، أبوء لك بنعمتك علي وأبوء لك بذنبي فاغفر لي فإنه لا يغفر الذنوب إلا أنت .
# ♦️ربنا آتنا في الدنيا حسنة وفي الآخرة حسنة وقنا عذاب النار ، اللهم إنك عفو تحب العفو فاعف عني.
#
# قال تعالى: «  يَا أَيُّهَا الَّذِينَ آمَنُوا اذْكُرُوا اللَّهَ ذِكْرًا كَثِيرًا  وَسَبِّحُوهُ بُكْرَةً وَأَصِيلا  هُوَ الَّذِي يُصَلِّي عَلَيْكُمْ وَمَلائِكَتُهُ لِيُخْرِجَكُمْ مِنَ الظُّلُمَاتِ إِلَى النُّورِ وَكَانَ بِالْمُؤْمِنِينَ رَحِيمًا  تَحِيَّتُهُمْ يَوْمَ يَلْقَوْنَهُ سَلَامٌ وَأَعَدَّ لَهُمْ أَجْرًا كَرِيمًا »

# %%
# 1. Colonnes texte à vérifier
text_fields = [
    "comment_id", "user_id", "user_name", "message", "created_time"
]

print("🧪 Champs texte vides (commentaires) :")
for col in text_fields:
    empty_count = (comments_df[col].astype(str).str.strip() == '').sum()
    print(f" - {col}: {empty_count} lignes vides")

# 2. Vérification created_time valide
print("\n🕒 Vérification des timestamps invalides (commentaires) :")
invalid_dates = pd.to_datetime(comments_df["created_time"], errors="coerce").isna().sum()
print(f" - created_time non valides : {invalid_dates}")

# 3. Valeurs uniques des booléens (si existent, ex: can_like, peut être adapté à ton cas)
bool_fields = [col for col in ["can_like"] if col in comments_df.columns]

print("\n🔁 Valeurs uniques booléennes (commentaires) :")
for col in bool_fields:
    print(f" - {col}: {comments_df[col].nunique()} valeurs uniques ({comments_df[col].unique()})")

# 4. Champs numériques : valeurs à 0
numeric_fields = [col for col in ["like_count", "reply_count"] if col in comments_df.columns]

print("\n🔢 Champs numériques avec des zéros (commentaires) :")
for col in numeric_fields:
    zero_count = (comments_df[col] == 0).sum()
    print(f" - {col} == 0 : {zero_count} lignes")

# 5. Listes : hashtags et mentions dans les commentaires (si présents)
list_fields = [col for col in ["hashtags", "mentions"] if col in comments_df.columns]

print("\n📚 Vérification des champs listes (commentaires) :")
for col in list_fields:
    non_lists = comments_df[~comments_df[col].apply(lambda x: isinstance(x, list))].shape[0]
    empty_lists = comments_df[comments_df[col].apply(lambda x: isinstance(x, list) and len(x) == 0)].shape[0]
    print(f" - {col} : {non_lists} non-listes / {empty_lists} listes vides")
# Out:
# 🧪 Champs texte vides (commentaires) :
#  - comment_id: 0 lignes vides
#  - user_id: 0 lignes vides
#  - user_name: 0 lignes vides
#  - message: 466 lignes vides
#  - created_time: 0 lignes vides
#
# 🕒 Vérification des timestamps invalides (commentaires) :
#  - created_time non valides : 0
#
# 🔁 Valeurs uniques booléennes (commentaires) :
#
# 🔢 Champs numériques avec des zéros (commentaires) :
#  - like_count == 0 : 16570 lignes
#  - reply_count == 0 : 16336 lignes
#
# 📚 Vérification des champs listes (commentaires) :
